# %%
import cloudscraper
#Creates cloud scraper to bypass cloudflare
scraper = cloudscraper.create_scraper()
#Gets market index cookie.
scraper.get("https://www.marketindex.com.au")
# Out:
# <Response [200]>

# %%
ticker = "COF"
limit = 20
url = f"https://data-api.marketindex.com.au/api/v1/announcements?codes={ticker}%3AAUD%3AXASX&limit={limit}"
response = scraper.get(url=url)
response.raise_for_status()
response.json()["data"]["announcements"]
# Out:
# [{'id': 2029956,
#   'identifier': 'XASX:COF:2A1654634',
#   'fileId': '2A1654634',
#   'pageCount': 25,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 846523,
#   'heading': 'Change in substantial holding',
#   'dateTime': '2026-02-19T21:20:50.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2026/02/20/2A1654634.pdf',
#   'types': [{'id': 5, 'identifier': '5', 'title': 'Security Holder Notices'}]},
#  {'id': 2023403,
#   'identifier': 'XASX:COF:2A1651396',
#   'fileId': '2A1651396',
#   'pageCount': 33,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 6901467,
#   'heading': 'COF HY26 Property Compendium',
#   'dateTime': '2026-02-03T22:15:26.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2026/02/04/2A1651396.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 2023407,
#   'identifier': 'XASX:COF:2A1651393',
#   'fileId': '2A1651393',
#   'pageCount': 37,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 9235455,
#   'heading': 'COF HY26 Results Presentation',
#   'dateTime': '2026-02-03T22:14:56.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2026/02/04/2A1651393.pdf',
#   'types': [{'id': 15, 'identifier': '15', 'title': 'Other'},
#    {'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 2023401,
#   'identifier': 'XASX:COF:2A1651392',
#   'fileId': '2A1651392',
#   'pageCount': 3,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 491231,
#   'heading': 'COF HY26 Results Announcement',
#   'dateTime': '2026-02-03T22:14:16.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2026/02/04/2A1651392.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 2023390,
#   'identifier': 'XASX:COF:2A1651390',
#   'fileId': '2A1651390',
#   'pageCount': 25,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 2702614,
#   'heading': 'COF HY26 Financial Report',
#   'dateTime': '2026-02-03T22:10:31.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2026/02/04/2A1651390.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 2023386,
#   'identifier': 'XASX:COF:2A1651389',
#   'fileId': '2A1651389',
#   'pageCount': 1,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 399472,
#   'heading': 'COF HY26 Appendix 4D',
#   'dateTime': '2026-02-03T22:07:06.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2026/02/04/2A1651389.pdf',
#   'types': [{'id': 4, 'identifier': '4', 'title': 'Dividend Notices'},
#    {'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 2019972,
#   'identifier': 'XASX:COF:2A1649968',
#   'fileId': '2A1649968',
#   'pageCount': 1,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 219614,
#   'heading': 'HY26 Results Date & Webcast Details',
#   'dateTime': '2026-01-27T23:36:53.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2026/01/28/2A1649968.pdf',
#   'types': [{'id': 15, 'identifier': '15', 'title': 'Other'}]},
#  {'id': 2000324,
#   'identifier': 'XASX:COF:2A1643755',
#   'fileId': '2A1643755',
#   'pageCount': 1,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 243283,
#   'heading': 'Chatswood office divested at 12.5% premium to book value',
#   'dateTime': '2025-12-17T22:58:09.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2025/12/18/2A1643755.pdf',
#   'types': [{'id': 15, 'identifier': '15', 'title': 'Other'}]},
#  {'id': 1994759,
#   'identifier': 'XASX:COF:2A1641343',
#   'fileId': '2A1641343',
#   'pageCount': 1,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 222346,
#   'heading': 'December 2025 Distribution Declaration',
#   'dateTime': '2025-12-04T22:20:24.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/12/05/2A1641343.pdf',
#   'types': [{'id': 4, 'identifier': '4', 'title': 'Dividend Notices'}]},
#  {'id': 1994732,
#   'identifier': 'XASX:COF:2A1641334',
#   'fileId': '2A1641334',
#   'pageCount': 4,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 13776,
#   'heading': 'Dividend/Distribution - COF',
#   'dateTime': '2025-12-04T22:09:09.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/12/05/2A1641334.pdf',
#   'types': [{'id': 4, 'identifier': '4', 'title': 'Dividend Notices'}]},
#  {'id': 1976139,
#   'identifier': 'XASX:COF:2A1632611',
#   'fileId': '2A1632611',
#   'pageCount': 2,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 276789,
#   'heading': 'Q1 FY26 Operating Update',
#   'dateTime': '2025-10-29T22:42:43.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/10/30/2A1632611.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 1958849,
#   'identifier': 'XASX:COF:2A1624965',
#   'fileId': '2A1624965',
#   'pageCount': 26,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 6014603,
#   'heading': 'Appendix 4G and Corporate Governance Statement',
#   'dateTime': '2025-09-29T05:44:15.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2025/09/29/2A1624965.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'},
#    {'id': 15, 'identifier': '15', 'title': 'Other'}]},
#  {'id': 1958850,
#   'identifier': 'XASX:COF:2A1624969',
#   'fileId': '2A1624969',
#   'pageCount': 41,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 8773432,
#   'heading': '2025 Annual Report',
#   'dateTime': '2025-09-29T05:44:10.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2025/09/29/2A1624969.pdf',
#   'types': [{'id': 3, 'identifier': '3', 'title': 'Annual Reports'},
#    {'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 1947769,
#   'identifier': 'XASX:COF:2A1619741',
#   'fileId': '2A1619741',
#   'pageCount': 1,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 222328,
#   'heading': 'September 2025 Distribution Declaration',
#   'dateTime': '2025-09-04T23:09:36.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/09/05/2A1619741.pdf',
#   'types': [{'id': 4, 'identifier': '4', 'title': 'Dividend Notices'}]},
#  {'id': 1947760,
#   'identifier': 'XASX:COF:2A1619740',
#   'fileId': '2A1619740',
#   'pageCount': 4,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 13771,
#   'heading': 'Dividend/Distribution - COF',
#   'dateTime': '2025-09-04T23:04:41.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/09/05/2A1619740.pdf',
#   'types': [{'id': 4, 'identifier': '4', 'title': 'Dividend Notices'}]},
#  {'id': 1936347,
#   'identifier': 'XASX:COF:2A1613876',
#   'fileId': '2A1613876',
#   'pageCount': 33,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 7005473,
#   'heading': 'COF FY25 Property Compendium',
#   'dateTime': '2025-08-14T23:19:03.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/08/15/2A1613876.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 1936340,
#   'identifier': 'XASX:COF:2A1613873',
#   'fileId': '2A1613873',
#   'pageCount': 35,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 8894144,
#   'heading': 'COF FY25 Results Presentation',
#   'dateTime': '2025-08-14T23:17:33.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/08/15/2A1613873.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'},
#    {'id': 15, 'identifier': '15', 'title': 'Other'}]},
#  {'id': 1936337,
#   'identifier': 'XASX:COF:2A1613870',
#   'fileId': '2A1613870',
#   'pageCount': 4,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 277898,
#   'heading': 'COF FY25 Results Announcement',
#   'dateTime': '2025-08-14T23:16:48.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/08/15/2A1613870.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 1936339,
#   'identifier': 'XASX:COF:2A1613868',
#   'fileId': '2A1613868',
#   'pageCount': 41,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 2433865,
#   'heading': 'COF FY25 Financial Report',
#   'dateTime': '2025-08-14T23:16:23.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2025/08/15/2A1613868.pdf',
#   'types': [{'id': 3, 'identifier': '3', 'title': 'Annual Reports'},
#    {'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 1936334,
#   'identifier': 'XASX:COF:2A1613865',
#   'fileId': '2A1613865',
#   'pageCount': 2,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 403732,
#   'heading': 'COF FY25 Appendix 4E',
#   'dateTime': '2025-08-14T23:15:13.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/08/15/2A1613865.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]}]

# %%
dd.get

# %%
import requests
import os
import time
from random import random
import pandas as pd
from datetime import datetime
import cloudscraper


class DocumentDownloader():
    def __init__(self):
        print("DocumentDownloader initialized...")

        #Creates cloud scraper to bypass cloudflare
        self.scraper = cloudscraper.create_scraper()
        #Gets market index cookie.
        self.scraper.get("https://www.marketindex.com.au")

        
    def get_announcements(self, ticker: str, limit: int = 20):
    
        url = f"https://data-api.marketindex.com.au/api/v1/announcements?codes={ticker}%3AAUD%3AXASX&limit={limit}"
        response = self.scraper.get(url=url)
        response.raise_for_status()
        return response.json()["data"]["announcements"]

    def download_pdf(self, identifier: str, filename:str, save_dir: str = "pdfs"):
        base_url = "https://data-api.marketindex.com.au/api/v1/announcements/"
        pdf_url = base_url + identifier + "/pdf"
        os.makedirs(save_dir, exist_ok=True)
        # filename = pdf_url.split("/")[-2]
        filepath = os.path.join(save_dir, filename)


        #Check if file already exists. Only executes if file does not exist. 
        if not os.path.exists(filepath):
        
            response = self.scraper.get(pdf_url)
            print(response)
            if response.status_code == 200:
                with open(filepath, "wb") as f:
                    f.write(response.content)
                    print(f"Downloaded: {filename}")
            else:
                print(f"Failed to download {filename}: {response.status_code}")


    def create_announcement_df(self, ticker_list:list,limit:int = 100):
    
        #Used for creating announcements dataframe.  
        ls_announcements = []

        #To be generalized in future to extract other documents such as sustainability reports and annual reports. 
        #Extracts only investor presentations.
        # 
        print("above ticker list") 
        for ticker in ticker_list:
            try:
                announcements = self.get_announcements(ticker,limit)

                print("announcements run here")
                for announcement in announcements:

                    #Check for whether announcement type is other; investor presentations are usuallly under 'other'. 
                    announcement_type = announcement['types'][0]['title']
                    announcement['ticker'] = ticker

                    print(ticker, announcement['heading'],announcement_type) 
                
                ls_announcements.extend(announcements)

                time.sleep(2 + random()*4)
                
            except Exception as e:
                print(f"Error processing {ticker}: {e}")

        return pd.DataFrame(ls_announcements)


    def filter_df_heading_with_regex(self, df:pd.DataFrame ,regex_pattern:str):
        return df[df['heading'].str.contains(regex_pattern,case = False,na=False)]

    def filter_df_with_date(self,df:pd.DataFrame, from_date_YYYY_MM_DD:str, to_date_YYYY_MM_DD:str):
        df["ISO_date"] = pd.to_datetime(df['dateTime'])
        return df[df["ISO_date"].between(from_date_YYYY_MM_DD, to_date_YYYY_MM_DD)]

    def filter_df_heading_with_regex_and_date(self,df:pd.DataFrame, regex_pattern:str, from_date_YYYY_MM_DD:str, to_date_YYYY_MM_DD:str):
        df_filtered = self.filter_df_heading_with_regex(df, regex_pattern)
        df_filtered = self.filter_df_with_date(df_filtered, from_date_YYYY_MM_DD, to_date_YYYY_MM_DD)
        return df_filtered

    def download_pdfs_in_df(self, df: pd.DataFrame, doc_suffix, save_dir: str):
        
        #If no doc suffix is provided, dd will use heading as the suffix. 

        try: 
            for index, row in df.iterrows():
                identifier = row['identifier']
                print("Downloading ",row['heading'], ".....")
                
                if doc_suffix is None:
                    filename = f"{row['ticker']}_{row['heading']}"
                else:
                    filename = f"{row['ticker']}_{doc_suffix}"

            
                self.download_pdf(identifier, filename, save_dir)
                time.sleep(3+random()*10)   # Sleep to avoid overwhelming the server

        except Exception as e:
            print(f"Error processing row {row}: {e}")

    # General method for downloading files. Regex needs to be specified. 
    def download_documents(self, ticker_list: list, from_date_YYYY_MM_DD:str, to_date_YYYY_MM_DD:str, save_dir: str, regex_pattern: str, doc_suffix = None ,limit: int = 100):
        """
        Downloads the investor presentations for the given ticker list.
        
        Parameters:
        - ticker_list: List of stock tickers to process.
        - limit: Number of announcements to fetch per ticker.
        - save_dir: Directory to save the downloaded PDFs.
        - regex_pattern: Regex pattern to filter the announcements.
        - from_date_YYYY_MM_DD: Start date in YYYY-MM-DD format.
        """
        df_announcements = self.create_announcement_df(ticker_list, limit)
        df_filtered = self.filter_df_heading_with_regex_and_date(df_announcements, regex_pattern, from_date_YYYY_MM_DD=from_date_YYYY_MM_DD, to_date_YYYY_MM_DD=to_date_YYYY_MM_DD)
        
        print(f"Filtered {len(df_filtered)} announcements matching the criteria.")
        
        
        self.download_pdfs_in_df(df_filtered, doc_suffix = doc_suffix, save_dir = save_dir)


    #Converts date to CY. 
    def assign_period_CY(self,date_input):
        
        if isinstance(date_input, str):
            date = datetime.strptime(date_input, "%Y-%m-%d")
        else:
            date = date_input

        if date.month in [1, 2, 3]:
            return f"CY{str(date.year - 1)[-2:]}"
        elif date.month in [7, 8, 9]:
            return f"HY{str(date.year)[-2:]}"
        else:
            return None
        
    #Converts date to FY. 
    def assign_period_FY(self,date_input):
        
        if isinstance(date_input, str):
            date = datetime.strptime(date_input, "%Y-%m-%d")
        else:
            date = date_input

        if date.month in [1, 2, 3]:
            return f"HY{str(date.year)[-2:]}"
        elif date.month in [7, 8, 9]:
            return f"FY{str(date.year)[-2:]}"
        else:
            return None

    def download_results_presentations(self, ticker_list: list, from_date_YYYY_MM_DD:str, to_date_YYYY_MM_DD:str, limit: int = 100, save_dir: str = "datasets/co_presentations", regex_pattern: str = r'results presentation|result presentation'):
        """
        Downloads the results presentations for the given ticker list.
        
        Parameters:
        - ticker_list: List of stock tickers to process.
        - limit: Number of announcements to fetch per ticker.
        - save_dir: Directory to save the downloaded PDFs.
        - regex_pattern: Regex pattern to filter the announcements.
        - from_date_YYYY_MM_DD: Start date in YYYY-MM-DD format.
        """
        df_announcements = self.create_announcement_df(ticker_list, limit)
        df_filtered = self.filter_df_heading_with_regex_and_date(df_announcements, regex_pattern, from_date_YYYY_MM_DD=from_date_YYYY_MM_DD, to_date_YYYY_MM_DD=to_date_YYYY_MM_DD)
        
        print(f"Filtered {len(df_filtered)} announcements matching the criteria.")
        
        # self.download_pdfs_in_df(df_filtered, save_dir)

        try: 
            for index, row in df_filtered.iterrows():
                identifier = row['identifier']
                fileType = row['fileType']
                
                print("Downloading ",row['heading'], ".....")
                
                CY = self.assign_period_FY(row["ISO_date"])

                filename = f"{row['ticker']}_{CY}_IP.{fileType}"
                print(filename)
                self.download_pdf(identifier, filename, save_dir)
                time.sleep(3+random()*10)   # Sleep to avoid overwhelming the server

        except Exception as e:
            print(f"Error processing row {row}: {e}")

# %% [markdown]
# # Instantiate Document Downloader

# %%
#Instantiate DocumentDownloader class
dd = DocumentDownloader()
# Out:
# DocumentDownloader initialized...

# %%
dd.get_announcements("COF")
# Out:
# [{'id': 2029956,
#   'identifier': 'XASX:COF:2A1654634',
#   'fileId': '2A1654634',
#   'pageCount': 25,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 846523,
#   'heading': 'Change in substantial holding',
#   'dateTime': '2026-02-19T21:20:50.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2026/02/20/2A1654634.pdf',
#   'types': [{'id': 5, 'identifier': '5', 'title': 'Security Holder Notices'}]},
#  {'id': 2023403,
#   'identifier': 'XASX:COF:2A1651396',
#   'fileId': '2A1651396',
#   'pageCount': 33,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 6901467,
#   'heading': 'COF HY26 Property Compendium',
#   'dateTime': '2026-02-03T22:15:26.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2026/02/04/2A1651396.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 2023407,
#   'identifier': 'XASX:COF:2A1651393',
#   'fileId': '2A1651393',
#   'pageCount': 37,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 9235455,
#   'heading': 'COF HY26 Results Presentation',
#   'dateTime': '2026-02-03T22:14:56.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2026/02/04/2A1651393.pdf',
#   'types': [{'id': 15, 'identifier': '15', 'title': 'Other'},
#    {'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 2023401,
#   'identifier': 'XASX:COF:2A1651392',
#   'fileId': '2A1651392',
#   'pageCount': 3,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 491231,
#   'heading': 'COF HY26 Results Announcement',
#   'dateTime': '2026-02-03T22:14:16.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2026/02/04/2A1651392.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 2023390,
#   'identifier': 'XASX:COF:2A1651390',
#   'fileId': '2A1651390',
#   'pageCount': 25,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 2702614,
#   'heading': 'COF HY26 Financial Report',
#   'dateTime': '2026-02-03T22:10:31.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2026/02/04/2A1651390.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 2023386,
#   'identifier': 'XASX:COF:2A1651389',
#   'fileId': '2A1651389',
#   'pageCount': 1,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 399472,
#   'heading': 'COF HY26 Appendix 4D',
#   'dateTime': '2026-02-03T22:07:06.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2026/02/04/2A1651389.pdf',
#   'types': [{'id': 4, 'identifier': '4', 'title': 'Dividend Notices'},
#    {'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 2019972,
#   'identifier': 'XASX:COF:2A1649968',
#   'fileId': '2A1649968',
#   'pageCount': 1,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 219614,
#   'heading': 'HY26 Results Date & Webcast Details',
#   'dateTime': '2026-01-27T23:36:53.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2026/01/28/2A1649968.pdf',
#   'types': [{'id': 15, 'identifier': '15', 'title': 'Other'}]},
#  {'id': 2000324,
#   'identifier': 'XASX:COF:2A1643755',
#   'fileId': '2A1643755',
#   'pageCount': 1,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 243283,
#   'heading': 'Chatswood office divested at 12.5% premium to book value',
#   'dateTime': '2025-12-17T22:58:09.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2025/12/18/2A1643755.pdf',
#   'types': [{'id': 15, 'identifier': '15', 'title': 'Other'}]},
#  {'id': 1994759,
#   'identifier': 'XASX:COF:2A1641343',
#   'fileId': '2A1641343',
#   'pageCount': 1,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 222346,
#   'heading': 'December 2025 Distribution Declaration',
#   'dateTime': '2025-12-04T22:20:24.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/12/05/2A1641343.pdf',
#   'types': [{'id': 4, 'identifier': '4', 'title': 'Dividend Notices'}]},
#  {'id': 1994732,
#   'identifier': 'XASX:COF:2A1641334',
#   'fileId': '2A1641334',
#   'pageCount': 4,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 13776,
#   'heading': 'Dividend/Distribution - COF',
#   'dateTime': '2025-12-04T22:09:09.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/12/05/2A1641334.pdf',
#   'types': [{'id': 4, 'identifier': '4', 'title': 'Dividend Notices'}]},
#  {'id': 1976139,
#   'identifier': 'XASX:COF:2A1632611',
#   'fileId': '2A1632611',
#   'pageCount': 2,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 276789,
#   'heading': 'Q1 FY26 Operating Update',
#   'dateTime': '2025-10-29T22:42:43.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/10/30/2A1632611.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 1958849,
#   'identifier': 'XASX:COF:2A1624965',
#   'fileId': '2A1624965',
#   'pageCount': 26,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 6014603,
#   'heading': 'Appendix 4G and Corporate Governance Statement',
#   'dateTime': '2025-09-29T05:44:15.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2025/09/29/2A1624965.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'},
#    {'id': 15, 'identifier': '15', 'title': 'Other'}]},
#  {'id': 1958850,
#   'identifier': 'XASX:COF:2A1624969',
#   'fileId': '2A1624969',
#   'pageCount': 41,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 8773432,
#   'heading': '2025 Annual Report',
#   'dateTime': '2025-09-29T05:44:10.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2025/09/29/2A1624969.pdf',
#   'types': [{'id': 3, 'identifier': '3', 'title': 'Annual Reports'},
#    {'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 1947769,
#   'identifier': 'XASX:COF:2A1619741',
#   'fileId': '2A1619741',
#   'pageCount': 1,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 222328,
#   'heading': 'September 2025 Distribution Declaration',
#   'dateTime': '2025-09-04T23:09:36.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/09/05/2A1619741.pdf',
#   'types': [{'id': 4, 'identifier': '4', 'title': 'Dividend Notices'}]},
#  {'id': 1947760,
#   'identifier': 'XASX:COF:2A1619740',
#   'fileId': '2A1619740',
#   'pageCount': 4,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 13771,
#   'heading': 'Dividend/Distribution - COF',
#   'dateTime': '2025-09-04T23:04:41.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/09/05/2A1619740.pdf',
#   'types': [{'id': 4, 'identifier': '4', 'title': 'Dividend Notices'}]},
#  {'id': 1936347,
#   'identifier': 'XASX:COF:2A1613876',
#   'fileId': '2A1613876',
#   'pageCount': 33,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 7005473,
#   'heading': 'COF FY25 Property Compendium',
#   'dateTime': '2025-08-14T23:19:03.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/08/15/2A1613876.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 1936340,
#   'identifier': 'XASX:COF:2A1613873',
#   'fileId': '2A1613873',
#   'pageCount': 35,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 8894144,
#   'heading': 'COF FY25 Results Presentation',
#   'dateTime': '2025-08-14T23:17:33.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/08/15/2A1613873.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'},
#    {'id': 15, 'identifier': '15', 'title': 'Other'}]},
#  {'id': 1936337,
#   'identifier': 'XASX:COF:2A1613870',
#   'fileId': '2A1613870',
#   'pageCount': 4,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 277898,
#   'heading': 'COF FY25 Results Announcement',
#   'dateTime': '2025-08-14T23:16:48.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/08/15/2A1613870.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 1936339,
#   'identifier': 'XASX:COF:2A1613868',
#   'fileId': '2A1613868',
#   'pageCount': 41,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 2433865,
#   'heading': 'COF FY25 Financial Report',
#   'dateTime': '2025-08-14T23:16:23.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': False,
#   'fileKey': 'announcements/xasx/2025/08/15/2A1613868.pdf',
#   'types': [{'id': 3, 'identifier': '3', 'title': 'Annual Reports'},
#    {'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]},
#  {'id': 1936334,
#   'identifier': 'XASX:COF:2A1613865',
#   'fileId': '2A1613865',
#   'pageCount': 2,
#   'symbolId': 'COF:AUD:XASX',
#   'securityName': 'Centuria Office REIT',
#   'fileSize': 403732,
#   'heading': 'COF FY25 Appendix 4E',
#   'dateTime': '2025-08-14T23:15:13.000Z',
#   'fileType': 'pdf',
#   'isPriceSensitive': True,
#   'fileKey': 'announcements/xasx/2025/08/15/2A1613865.pdf',
#   'types': [{'id': 2, 'identifier': '2', 'title': 'Periodic Reports'}]}]

# %%
dd.create_announcement_df(["COF"])
# Out:
# above ticker list
# announcements run here
# COF Change in substantial holding Security Holder Notices
# COF COF HY26 Property Compendium Periodic Reports
# COF COF HY26 Results Presentation Periodic Reports
# COF COF HY26 Results Announcement Periodic Reports
# COF COF HY26 Financial Report Periodic Reports
# COF COF HY26 Appendix 4D Dividend Notices
# COF HY26 Results Date & Webcast Details Other
# COF Chatswood office divested at 12.5% premium to book value Other
# COF December 2025 Distribution Declaration Dividend Notices
# COF Dividend/Distribution - COF Dividend Notices
# COF Q1 FY26 Operating Update Periodic Reports
# COF Appendix 4G and Corporate Governance Statement Other
# COF 2025 Annual Report Periodic Reports
# COF September 2025 Distribution Declaration Dividend Notices
# COF Dividend/Distribution - COF Dividend Notices
# COF COF FY25 Property Compendium Periodic Reports
# COF COF FY25 Results Presentation Other
# COF COF FY25 Results Announcement Periodic Reports
# COF COF FY25 Financial Report Annual Reports
# COF COF FY25 Appendix 4E Periodic Reports
# COF FY25 Results Date & Webcast Details Other
# COF June 2025 Distribution Declaration Dividend Notices
# COF Dividend/Distribution - COF Dividend Notices
# COF Q3 FY25 Operating Update Periodic Reports
# COF March 2025 Distribution Declaration Dividend Notices
# COF Dividend/Distribution - COF Dividend Notices
# COF COF HY25 Property Compendium Periodic Reports
# COF COF HY25 Results Presentation Other
# COF COF HY25 Results Announcement Periodic Reports
# COF COF HY25 Financial Report Periodic Reports
# COF COF HY25 Appendix 4D Dividend Notices
# COF December 2024 Distribution Declaration Dividend Notices
# COF Dividend/Distribution - COF Dividend Notices
# COF 2024 Climate-related Disclosures Periodic Reports
# COF 2024 Sustainability Report Other
# COF Q1 FY25 Operating Update Periodic Reports
# COF 2024 Annual Report Periodic Reports
# COF Appendix 4G and Corporate Governance Statement Other
# COF September 2024 Distribution Declaration Dividend Notices
# COF Dividend/Distribution - COF Dividend Notices
# COF Change in substantial holding Security Holder Notices
# COF Change in substantial holding Security Holder Notices
# COF COF FY24 Property Compendium Periodic Reports
# COF COF FY24 Results Presentation Other
# COF COF FY24 Results Announcement Periodic Reports
# COF COF FY24 Financial Report Periodic Reports
# COF COF FY24 Appendix 4E Periodic Reports
# COF FY24 Results Date & Webcast Details Other
# COF 555 Coronation Drive Settlement Other
# COF FY24 Portfolio valuations Periodic Reports
# COF June 2024 Distribution Declaration Dividend Notices
# COF Dividend/Distribution - COF Dividend Notices
# COF Non-core Toowong office divested addendum Other
# COF Non-core Toowong office divested Other
# COF Q3 FY24 Operating Update Periodic Reports
# COF New COF Fund Manager Appointed Company Administration
# COF March 2024 Distribution Declaration Dividend Notices
# COF Dividend/Distribution - COF Dividend Notices
# COF COF HY24 Property Compendium Periodic Reports
# COF COF HY24 Results Presentation Periodic Reports
# COF COF HY24 Results Announcement Periodic Reports
# COF COF HY24 Financial Report Periodic Reports
# COF COF HY24 Appendix 4D Periodic Reports
# COF Significant Lease Renewal William Square, WA Other
# COF 54 Marcus Clarke Street Settlement Other
# COF HY24 Results Date & Webcast Details Other
# COF HY24 Portfolio Valuations Periodic Reports
# COF December 2023 Distribution Declaration Dividend Notices
# COF Dividend/Distribution - COF Dividend Notices
# COF Change in substantial holding Security Holder Notices
# COF 2023 Sustainability Report Other
# COF Ceasing to be a substantial holder Security Holder Notices
# COF Q1 FY24 Operating Update Dividend Notices
# COF Change in substantial holding Security Holder Notices
# COF 2023 Annual Report Periodic Reports
# COF Appendix 4G and Corporate Governance Statement Other
# COF Change in substantial holding Security Holder Notices
# COF September 2023 Distribution Declaration Dividend Notices
# COF Dividend/Distribution - COF Dividend Notices
# COF COF FY23 Property Compendium Periodic Reports
# COF COF FY23 Results Presentation Other
# COF COF FY23 Results Announcement Periodic Reports
# COF COF FY23 Financial Report Annual Reports
# COF COF FY23 Appendix 4E Periodic Reports
# COF FY23 Results Date & Webcast Details Other
# COF Divestment of 35 Robina Town Centre Drive, Robina QLD Other
# COF FY23 Portfolio Valuations Periodic Reports
# COF $225M Debt Refinance and Non-Core Divestment Other
# COF June 2023 Distribution Declaration Dividend Notices
# COF Dividend/Distribution - COF Dividend Notices
# COF Q3 FY23 Operating Update Periodic Reports
# COF Dividend/Distribution - COF Dividend Notices
# COF March 2023 Distribution Declaration Dividend Notices
# COF COF HY23 Property Compendium Periodic Reports
# COF COF HY23 Results Presentation Other
# COF COF HY23 Results Announcement Periodic Reports
# COF COF HY23 Financial Report Periodic Reports
# COF COF HY23 Appendix 4D Dividend Notices
# COF HY23 Results Date & Webcast Details Other
# COF Change in substantial holding Security Holder Notices
#          id          identifier     fileId  pageCount      symbolId  \
# 0   2029956  XASX:COF:2A1654634  2A1654634         25  COF:AUD:XASX
# 1   2023403  XASX:COF:2A1651396  2A1651396         33  COF:AUD:XASX
# 2   2023407  XASX:COF:2A1651393  2A1651393         37  COF:AUD:XASX
# 3   2023401  XASX:COF:2A1651392  2A1651392          3  COF:AUD:XASX
# 4   2023390  XASX:COF:2A1651390  2A1651390         25  COF:AUD:XASX
# ..      ...                 ...        ...        ...           ...
# 95    53551  XASX:COF:2A1428487  2A1428487          4  COF:AUD:XASX
# 96    53558  XASX:COF:2A1428484  2A1428484         26  COF:AUD:XASX
# 97    53564  XASX:COF:2A1428481  2A1428481          1  COF:AUD:XASX
# 98    47147  XASX:COF:2A1425972  2A1425972          1  COF:AUD:XASX
# 99    41611  XASX:COF:2A1425740  2A1425740          3  COF:AUD:XASX
#
#             securityName  fileSize                              heading  \
# 0   Centuria Office REIT    846523        Change in substantial holding
# 1   Centuria Office REIT   6901467         COF HY26 Property Compendium
# 2   Centuria Office REIT   9235455        COF HY26 Results Presentation
# 3   Centuria Office REIT    491231        COF HY26 Results Announcement
# 4   Centuria Office REIT   2702614            COF HY26 Financial Report
# ..                   ...       ...                                  ...
# 95  Centuria Office REIT    220199        COF HY23 Results Announcement
# 96  Centuria Office REIT    540542            COF HY23 Financial Report
# 97  Centuria Office REIT    395740                 COF HY23 Appendix 4D
# 98  Centuria Office REIT    163481  HY23 Results Date & Webcast Details
# 99  Centuria Office REIT    151304        Change in substantial holding
#
#                     dateTime fileType  isPriceSensitive  \
# 0   2026-02-19T21:20:50.000Z      pdf             False
# 1   2026-02-03T22:15:26.000Z      pdf              True
# 2   2026-02-03T22:14:56.000Z      pdf              True
# 3   2026-02-03T22:14:16.000Z      pdf              True
# 4   2026-02-03T22:10:31.000Z      pdf             False
# ..                       ...      ...               ...
# 95  2023-02-01T22:21:38.000Z      pdf              True
# 96  2023-02-01T22:18:43.000Z      pdf             False
# 97  2023-02-01T22:17:03.000Z      pdf              True
# 98  2023-01-17T04:07:09.000Z      pdf             False
# 99  2023-01-16T03:05:53.000Z      pdf             False
#
#                                         fileKey  \
# 0   announcements/xasx/2026/02/20/2A1654634.pdf
# 1   announcements/xasx/2026/02/04/2A1651396.pdf
# 2   announcements/xasx/2026/02/04/2A1651393.pdf
# 3   announcements/xasx/2026/02/04/2A1651392.pdf
# 4   announcements/xasx/2026/02/04/2A1651390.pdf
# ..                                          ...
# 95  announcements/xasx/2023/02/02/2A1428487.pdf
# 96  announcements/xasx/2023/02/02/2A1428484.pdf
# 97  announcements/xasx/2023/02/02/2A1428481.pdf
# 98  announcements/xasx/2023/01/17/2A1425972.pdf
# 99  announcements/xasx/2023/01/16/2A1425740.pdf
#
#                                                 types ticker
# 0   [{'id': 5, 'identifier': '5', 'title': 'Securi...    COF
# 1   [{'id': 2, 'identifier': '2', 'title': 'Period...    COF
# 2   [{'id': 2, 'identifier': '2', 'title': 'Period...    COF
# 3   [{'id': 2, 'identifier': '2', 'title': 'Period...    COF
# 4   [{'id': 2, 'identifier': '2', 'title': 'Period...    COF
# ..                                                ...    ...
# 95  [{'id': 2, 'identifier': '2', 'title': 'Period...    COF
# 96  [{'id': 2, 'identifier': '2', 'title': 'Period...    COF
# 97  [{'id': 4, 'identifier': '4', 'title': 'Divide...    COF
# 98  [{'id': 15, 'identifier': '15', 'title': 'Othe...    COF
# 99  [{'id': 5, 'identifier': '5', 'title': 'Securi...    COF
#
# [100 rows x 14 columns]

# %%
f"https://data-api.marketindex.com.au/api/v1/announcements?codes={ticker}%3AAUD%3AXASX&limit={limit}"

# %% [markdown]
# # To download all investor presentations for a set of tickers published between two dates.

# %%
#Inputs
# ticker_list = ["COF","CIP","CQR","CQE","ARF","CLW","GMG"]
# from_date_YYYY_MM_DD = "2020-01-31"
# to_date_YYYY_MM_DD = "2026-03-31"

ticker_list = ["INA","CHC","HDN","HCW","SGP","MGR","SCG","VCX","ABG","ASK","BWP","CMW","DXS","DXI","DXC","GLF","GPT","LIC","NSR","QAL","RGN","WPR","COF","CIP","CQR","CQE","ARF","CLW","GMG"]
from_date_YYYY_MM_DD = "2015-01-31"
to_date_YYYY_MM_DD = "2026-03-31"
save_dir = "datasets/raw"

#download statements for tickers in ticker list.  
dd.download_results_presentations(
    ticker_list = ticker_list,
    from_date_YYYY_MM_DD=from_date_YYYY_MM_DD,
    to_date_YYYY_MM_DD=to_date_YYYY_MM_DD,
    save_dir=save_dir,
    limit=500
    )
# Out:
# above ticker list
# announcements run here
# INA Change in substantial holding from MQG Security Holder Notices
# INA 1H26 Property Portfolio Periodic Reports
# INA 1H26 Results Presentation Other
# INA Guidance Affirmed at Top of Range with Second Half Skew Other
# INA Dividend/Distribution - INA Dividend Notices
# INA Appendix 4D and Interim Financial Reports Dividend Notices
# INA Ceasing to be a substantial holder from MUFG Security Holder Notices
# INA Ceasing to be a substantial holder Security Holder Notices
# INA Notification of cessation of securities - INA Other
# INA Change in Directors' Interest Notices Security Holder Notices
# INA Change in substantial holding Security Holder Notices
# INA Initial Director's Interest Notice Security Holder Notices
# INA Appointment of Non-Executive Director Company Administration
# INA Becoming a substantial holder from MQG Security Holder Notices
# INA Change in Director's Interest Notice - John Carfi Director Transactions
# INA Notification regarding unquoted securities - INA Other
# INA 2025 Annual General Meeting Results AGMs
# INA 2025 AGM Chair and CEO Address and Presentation Other
# INA Ceasing to be a substantial holder from MQG Security Holder Notices
# INA Notification of cessation of securities - INA Other
# INA Notification regarding unquoted securities - INA Other
# INA Notification of cessation of securities - INA Other
# INA Notice of Meeting - 2025 Annual General Meeting AGMs
# INA Change in Director's Interest Notice - John Carfi Security Holder Notices
# INA Notification regarding unquoted securities - INA Other
# INA Ceasing to be a substantial holder Security Holder Notices
# INA Becoming a substantial holder Security Holder Notices
# INA Ceasing to be a substantial holder Security Holder Notices
# INA Becoming a substantial holder Security Holder Notices
# INA Appendix 4G Other
# INA 2025 Corporate Governance Statement Periodic Reports
# INA 2025 Annual Report Annual Reports
# INA Ceasing to be a substantial holder Security Holder Notices
# INA Request for information from Consumer Affairs Victoria Company Administration
# INA Becoming a substantial holder Security Holder Notices
# INA Ceasing to be a substantial holder Security Holder Notices
# INA 2025 AGM and Closing Date for Director Nominations AGMs
# INA FY25 Property Portfolio Periodic Reports
# INA FY25 Results Presentation Other
# INA Strategy Delivering - Underlying EPS Guidance Exceeded Periodic Reports
# INA Dividend/Distribution - INA Dividend Notices
# INA Appendix 4E and Financial Reports Dividend Notices
# INA Becoming a substantial holder from MUFG Security Holder Notices
# INA Becoming a substantial holder Security Holder Notices
# INA Ceasing to be a substantial holder from MUFG Security Holder Notices
# INA Ceasing to be a substantial holder Security Holder Notices
# INA Update on Deferred Management Fee Company Administration
# INA Becoming a substantial holder Security Holder Notices
# INA Ceasing to be a substantial holder Security Holder Notices
# INA Notification of cessation of securities - INA Other
# INA Change in substantial holding from MQG - Amendment Filing Security Holder Notices
# INA Becoming a substantial holder Security Holder Notices
# INA Becoming a substantial holder from MUFG Security Holder Notices
# INA Becoming a substantial holder Security Holder Notices
# INA
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Change in substantial holding Security Holder Notices
# CHC Becoming a substantial holder from MUFG Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder from CBA Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Change of Director's Interest Notice Director Transactions
# CHC Capital Reallocation Other
# CHC Ceasing to be a substantial holder from MUFG Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Change of Director's Interest Notice Director Transactions
# CHC Becoming a substantial holder Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Fund Payment Notice Dividend Notices
# CHC HY25 Results Presentation Other
# CHC HY25 ASX Release Periodic Reports
# CHC HY25 Financial Report Periodic Reports
# CHC Appendix 4D Periodic Reports
# CHC Becoming a substantial holder from CBA Security Holder Notices
# CHC Ceasing to be a substantial holder from CBA Security Holder Notices
# CHC Becoming a substantial holder from CBA Security Holder Notices
# CHC Change in substantial holding from MUFG Security Holder Notices
# CHC Change in substantial holding Security Holder Notices
# CHC Ceasing to be a substantial holder from CBA Security Holder Notices
# CHC Distribution for the half-year ending 31 December 2024 Dividend Notices
# CHC Dividend/Distribution - CHC Dividend Notices
# CHC Change in substantial holding Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Change of Director's Interest Notice Security Holder Notices
# CHC Change of Director's Interest Notice Director Transactions
# CHC Notification regarding unquoted securities - CHC Other
# CHC Final Director's Interest Notice Security Holder Notices
# CHC Amended Constitutions Company Administration
# CHC Results of AGM AGMs
# CHC AGM - Chair and CEO Addresses Other
# CHC AGM Presentation Other
# CHC Becoming a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Becoming a substantial holder from CBA Security Holder Notices
# CHC Initial Director's Interest Notice Security Holder Notices
# CHC Notice of AGM and Proxy Form Other
# CHC Director Appointment Company Administration
# CHC Change in substantial holding Security Holder Notices
# CHC Change in substantial holding Security Holder Notices
# CHC Securities Trading Policy Other
# CHC Chair Retirement and Appointment Other
# CHC Becoming a substantial holder Security Holder Notices
# CHC Change of Director's Interest Notice Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder from CBA Security Holder Notices
# CHC Becoming a substantial holder from CBA Security Holder Notices
# CHC Response to ASX Aware Letter ASX Queries
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder from CBA Security Holder Notices
# CHC Fund Payment Notice Dividend Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Sustainability Report Other
# CHC Appendix 4G Other
# CHC Corporate Governance Statement Periodic Reports
# CHC FY24 Results - Presentation Other
# CHC FY24 Results - Release Dividend Notices
# CHC Annual Report Annual Reports
# CHC Appendix 4E Dividend Notices
# CHC Distribution for the half-year ending 30 June 2024 Dividend Notices
# CHC Dividend/Distribution - CHC Dividend Notices
# CHC Change in substantial holding Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Notification of cessation of securities - CHC Other
# CHC Acquisition of a 14.8% interest in HPI by CHC and CQR Other
# CHC Change of Director's Interest Notice Director Transactions
# CHC Fund Payment Notice Dividend Notices
# CHC Change in substantial holding Security Holder Notices
# CHC HY24 Results Presentation Periodic Reports
# CHC HY24 ASX Release Dividend Notices
# CHC HY24 Financial Report Periodic Reports
# CHC Appendix 4D Dividend Notices
# CHC Notification regarding unquoted securities - CHC Other
# CHC Change of Director's Interest Notice Security Holder Notices
# CHC Distribution for half-year ended 31 December 2023 Dividend Notices
# CHC Dividend/Distribution - CHC Dividend Notices
# CHC Results of AGM AGMs
# CHC AGM - Presentation Other
# CHC AGM - Chair and CEO Addresses Other
# CHC Change in substantial holding from MUFG Security Holder Notices
# CHC Change in substantial holding Security Holder Notices
# CHC Notice of Annual General Meeting/Proxy Form AGMs
# CHC Appointment of CFO Company Administration
# CHC Resignation of CFO Company Administration
# CHC Becoming a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Change of Director's Interest Notice Director Transactions
# CHC Becoming a substantial holder Security Holder Notices
# CHC Fund Payment Notice Dividend Notices
# CHC Appendix 4G Other
# CHC Corporate Governance Statement Periodic Reports
# CHC FY23 Results - Presentation Other
# CHC FY23 Results - Release Periodic Reports
# CHC Annual Report Periodic Reports
# CHC Appendix 4E Periodic Reports
# CHC Change in substantial holding Security Holder Notices
# CHC Distribution for the half-year ending 30 June 2023 Dividend Notices
# CHC Dividend/Distribution - CHC Dividend Notices
# CHC Development Showcase Other
# CHC Property platform June 2023 valuation update Other
# CHC Change in substantial holding Security Holder Notices
# CHC Change of Director's Interest Notice Director Transactions
# CHC Change of Director's Interest Notice Security Holder Notices
# CHC Change in substantial holding from MUFG Security Holder Notices
# CHC Change in substantial holding Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Change of Director's Interest Notice Director Transactions
# CHC Fund Payment Notice Dividend Notices
# CHC HY23 Results - Presentation Other
# CHC HY23 Results - Release Periodic Reports
# CHC Appendix 4D and HY23 Financial Statements Dividend Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Initial Director's Interest Notice Security Holder Notices
# CHC Appointment of Director Company Administration
# CHC Becoming a substantial holder Security Holder Notices
# CHC Property Platform December 2022 valuation update Periodic Reports
# CHC Distribution for half-year ending 31 December 2022 Dividend Notices
# CHC Dividend/Distribution - CHC Dividend Notices
# CHC Change of Director's Interest Notice Director Transactions
# CHC Notification regarding unquoted securities - CHC Other
# CHC Change of Director's Interest Notice Security Holder Notices
# CHC Results of AGM AGMs
# CHC 2022 AGM Chair and CEO Addresses Other
# CHC 2022 AGM Presentation Other
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Notice of Annual General Meeting/Proxy Form AGMs
# CHC Becoming a substantial holder Security Holder Notices
# CHC 2022 Sustainability Report Other
# CHC Change of Director's Interest Notice Security Holder Notices
# CHC Fund Payment Notice Dividend Notices
# CHC Appendix 4G Other
# CHC Corporate Governance Statement Periodic Reports
# CHC FY22 Results - Presentation Periodic Reports
# CHC FY22 Results - Announcement Periodic Reports
# CHC FY22 Annual Report Periodic Reports
# CHC Appendix 4E Periodic Reports
# CHC Change in substantial holding Security Holder Notices
# CHC Change in substantial holding from CBA Security Holder Notices
# CHC Change in substantial holding Security Holder Notices
# CHC 30 June 2022 Distribution Dividend Notices
# CHC Dividend/Distribution - CHC Dividend Notices
# CHC Change in substantial holding from MUFG Security Holder Notices
# CHC Change in substantial holding Security Holder Notices
# CHC Change of Director's Interest Notice Director Transactions
# CHC Irongate Group and 360REIT Acquisition of Assets Other
# CHC IAP:Irongate recommends proposal and enters into an SIA Other
# CHC Charter Hall partnership enters SIA to acquire Irongate Dividend Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Change of Director's Interest Notice Director Transactions
# CHC Fund Payment Notice Dividend Notices
# CHC 1H FY22 Results - Presentation Other
# CHC Upgraded Earnings Guidance and 1H FY22 Results - Release Periodic Reports
# CHC HY22 Financial Statements Periodic Reports
# CHC Appendix 4D Periodic Reports
# CHC IAP: Update non-binding indicative proposal to acquire IAP Other
# CHC IAP: Non-binding, indicative proposal from Charter Hall Other
# CHC Change in substantial holding from CBA Security Holder Notices
# CHC Cleansing Statement Other
# CHC Application for quotation of securities - CHC Other
# CHC Proposed issue of securities - CHC Non-Procedural
# CHC Partnership with Paradice Investment Management - Pres Other
# CHC Partnership with Paradice Investment Management - Release Other
# CHC Change of Director's Interest Notice Security Holder Notices
# CHC Notification regarding unquoted securities - CHC Other
# CHC Upgraded FY22 earnings guidance and FUM growth update Other
# CHC Distribution for the half-year ending 31 December 2021 Dividend Notices
# CHC Dividend/Distribution - CHC Dividend Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Final Director's Interest Notice Security Holder Notices
# CHC Retirement of Philip Garling Company Administration
# CHC Results of AGM AGMs
# CHC AGM Chair and CEO Addresses Other
# CHC AGM Presentation Other
# CHC Upgraded FY22 earnings guidance Periodic Reports
# CHC Notice of 2021 Annual General Meeting Other
# CHC Change of Director's Interest Notice Security Holder Notices
# CHC Sustainability Report 2021 Periodic Reports
# CHC Appendix 4G Other
# CHC Corporate Governance Statement Periodic Reports
# CHC Annual Report Periodic Reports
# CHC Change of Director's Interest Notice Director Transactions
# CHC Fund Payment Notice Dividend Notices
# CHC Full Year Results - Presentation Periodic Reports
# CHC Full Year Results - Media Release Periodic Reports
# CHC Full Year Financial Report Periodic Reports
# CHC Appendix 4E Dividend Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Charter Hall FUM rises to $52 billion Other
# CHC Becoming a substantial holder Security Holder Notices
# CHC Dividend/Distribution - CHC Dividend Notices
# CHC Distribution for the half-year ending 30 June 2021 Dividend Notices
# CHC Final Director's Interest Notice Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Upgraded Earnings Guidance Periodic Reports
# CHC Retirement of Anne Brennan as Non-Executive Director Company Administration
# CHC CHC secures $250 million of 10-year debt Periodic Reports
# CHC Development Showcase Presentation Other
# CHC Becoming a substantial holder Security Holder Notices
# CHC AOF: Market Update Other
# CHC CHAB acquires 241 Adelaide Street Brisbane Other
# CHC ABP: CHAB acquires 241 Adelaide Street, Brisbane Other
# CHC Change of Director's Interest Notice Director Transactions
# CHC Change of Director's Interest Notice Security Holder Notices
# CHC Change of Director's Interest Notice Director Transactions
# CHC Fund Payment Notice Dividend Notices
# CHC Change of Director's Interest Notice Director Transactions
# CHC Initial Director's Interest Notice Security Holder Notices
# CHC Appointment of new Director Company Administration
# CHC HY21 Results - Presentation Periodic Reports
# CHC HY21 Results - Media Release Periodic Reports
# CHC Appendix 4D and HY21 Financial Statements Periodic Reports
# CHC Change in substantial holding from MUFG Security Holder Notices
# CHC $510m acquisition of David Jones flagship Sydney CBD store Other
# CHC Distribution for the half-year ending 31 December 2020 Dividend Notices
# CHC Dividend/Distribution - CHC Dividend Notices
# CHC 555 Collins Street Update Other
# CHC Appendix 3G Other
# CHC Change of Director's Interest Notice Director Transactions
# CHC Charter Hall Partnership acquires Bunnings Portfolio Other
# CHC Results of AGM AGMs
# CHC AGM Presentation Other
# CHC FY20 AGM Chair and CEO Addresses Other
# CHC Charter Hall Group Market Update Other
# CHC AGM Notice of Meeting and Sample Proxy Form AGMs
# CHC Becoming a substantial holder Security Holder Notices
# CHC Sustainability Report Periodic Reports
# CHC Appendix 4G Other
# CHC Corporate Governance Statement Periodic Reports
# CHC Annual Report Periodic Reports
# CHC Extending the bp Partnership Other
# CHC Change of Director's Interest Notice Security Holder Notices
# CHC AMIT - Fund Payment Notice Dividend Notices
# CHC FY20 Results - Presentation Periodic Reports
# CHC FY20 Results - Media Release Periodic Reports
# CHC Appendix 4E and FY20 Financial Report Periodic Reports
# CHC CHC & GIC acquire $682m stake in $1.4bn Ampol portfolio Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Sale of stake in Waypoint REIT Other
# CHC Charter Hall appoints new Office CEO Company Administration
# CHC Charter Hall funds acquire $207m industrial investment Other
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC 2HFY20 Distribution - Update Dividend Notices
# CHC 2HFY20 Distribution Dividend Notices
# CHC Dividend/Distribution - CHC Dividend Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Change in substantial holding from CBA Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Market Update Periodic Reports
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC CHOT Performance Fee & Earnings Guidance Update Periodic Reports
# CHC AMIT Notice Dividend Notices
# CHC Becoming a substantial holder Security Holder Notices
# CHC Charter Hall Transactions Security Holder Notices
# CHC Acquisition of stake in VVR Security Holder Notices
# CHC VEA:Viva Energy agrees to sell 35.5 percent of Viva Energy R Security Holder Notices
# CHC HY20 Results - Presentation Other
# CHC HY20 Results - Media Release Periodic Reports
# CHC Appendix 4D and HY20 Financial Report Dividend Notices
# CHC Change in substantial holding from MUFG Security Holder Notices
# CHC Change in substantial holding Security Holder Notices
# CHC Ceasing to be a substantial holder Security Holder Notices
# CHC Becoming a substantial holder Security Holder Notices
# ...
# <Response [200]>
# Downloaded: NSR_FY22_IP.pdf
# Downloading  NSR Half Year Results Presentation .....
# NSR_HY22_IP.pdf
# <Response [200]>
# Downloaded: NSR_HY22_IP.pdf
# Downloading  NSR 2021 Results Presentation .....
# NSR_FY21_IP.pdf
# <Response [200]>
# Downloaded: NSR_FY21_IP.pdf
# Downloading  NSR Half Year Results Presentation .....
# NSR_HY21_IP.pdf
# <Response [200]>
# Downloaded: NSR_HY21_IP.pdf
# Downloading  NSR 2020 Results Presentation .....
# NSR_FY20_IP.pdf
# <Response [200]>
# Downloaded: NSR_FY20_IP.pdf
# Downloading  NSR Half Year Results Presentation .....
# NSR_HY20_IP.pdf
# <Response [200]>
# Downloaded: NSR_HY20_IP.pdf
# Downloading  NSR 2019 Results Presentation .....
# NSR_FY19_IP.pdf
# <Response [200]>
# Downloaded: NSR_FY19_IP.pdf
# Downloading  NSR Half Year Results Presentation .....
# NSR_HY19_IP.pdf
# <Response [200]>
# Downloaded: NSR_HY19_IP.pdf
# Downloading  NSR 2018 Results Presentation .....
# NSR_FY18_IP.pdf
# <Response [200]>
# Downloaded: NSR_FY18_IP.pdf
# Downloading  NSR Half Year Results Presentation .....
# NSR_HY18_IP.pdf
# <Response [200]>
# Downloaded: NSR_HY18_IP.pdf
# Downloading  1H26 Results Presentation .....
# QAL_HY26_IP.pdf
# <Response [200]>
# Downloaded: QAL_HY26_IP.pdf
# Downloading  Full Year 2025 Results Presentation .....
# QAL_FY25_IP.pdf
# <Response [200]>
# Downloaded: QAL_FY25_IP.pdf
# Downloading  1H25 Results Presentation .....
# QAL_HY25_IP.pdf
# <Response [200]>
# Downloaded: QAL_HY25_IP.pdf
# Downloading  Full Year 2024 Results Presentation .....
# QAL_FY24_IP.pdf
# <Response [200]>
# Downloaded: QAL_FY24_IP.pdf
# Downloading  1H24 Results Presentation .....
# QAL_HY24_IP.pdf
# <Response [200]>
# Downloaded: QAL_HY24_IP.pdf
# Downloading  Full Year 2023 Results Presentation .....
# QAL_FY23_IP.pdf
# <Response [200]>
# Downloaded: QAL_FY23_IP.pdf
# Downloading  1H23 Results Presentation .....
# QAL_HY23_IP.pdf
# <Response [200]>
# Downloaded: QAL_HY23_IP.pdf
# Downloading  Full Year 2022 Results Presentation .....
# QAL_FY22_IP.pdf
# <Response [200]>
# Downloaded: QAL_FY22_IP.pdf
# Downloading  1H FY 22 Results Presentation .....
# QAL_HY22_IP.pdf
# <Response [200]>
# Downloaded: QAL_HY22_IP.pdf
# Downloading  Region Group FY25 Results Presentation .....
# RGN_FY25_IP.pdf
# <Response [200]>
# Downloaded: RGN_FY25_IP.pdf
# Downloading  Region Group FY24 Results Presentation .....
# RGN_FY24_IP.pdf
# <Response [200]>
# Downloaded: RGN_FY24_IP.pdf
# Downloading  Region Group FY23 Results Presentation .....
# RGN_FY23_IP.pdf
# <Response [200]>
# Downloaded: RGN_FY23_IP.pdf
# Downloading  SCA Property Group FY22 Results Presentation .....
# RGN_FY22_IP.pdf
# <Response [200]>
# Downloaded: RGN_FY22_IP.pdf
# Downloading  SCA Property Group FY21 Results Presentation .....
# RGN_FY21_IP.pdf
# <Response [200]>
# Downloaded: RGN_FY21_IP.pdf
# Downloading  SCA Property Group FY20 Results Presentation .....
# RGN_FY20_IP.pdf
# <Response [200]>
# Downloaded: RGN_FY20_IP.pdf
# Downloading  SCA Property Group FY19 Results Presentation .....
# RGN_FY19_IP.pdf
# <Response [200]>
# Downloaded: RGN_FY19_IP.pdf
# Downloading  SCA Property Group FY18 Results Presentation .....
# RGN_FY18_IP.pdf
# <Response [200]>
# Downloaded: RGN_FY18_IP.pdf
# Downloading  Waypoint REIT Results Presentation FY25 .....
# WPR_HY26_IP.pdf
# <Response [200]>
# Downloaded: WPR_HY26_IP.pdf
# Downloading  1H2025 Results Presentation .....
# WPR_FY25_IP.pdf
# <Response [200]>
# Downloaded: WPR_FY25_IP.pdf
# Downloading  Waypoint REIT Results Presentation FY24 .....
# WPR_HY25_IP.pdf
# <Response [200]>
# Downloaded: WPR_HY25_IP.pdf
# Downloading  HY24 Results Presentation .....
# WPR_FY24_IP.pdf
# <Response [200]>
# Downloaded: WPR_FY24_IP.pdf
# Downloading  Waypoint REIT Results Presentation FY23 .....
# WPR_HY24_IP.pdf
# <Response [200]>
# Downloaded: WPR_HY24_IP.pdf
# Downloading  HY23 Results Presentation .....
# WPR_FY23_IP.pdf
# <Response [200]>
# Downloaded: WPR_FY23_IP.pdf
# Downloading  Waypoint REIT FY22 Results Presentation .....
# WPR_HY23_IP.pdf
# <Response [200]>
# Downloaded: WPR_HY23_IP.pdf
# Downloading  HY22 Results Presentation .....
# WPR_FY22_IP.pdf
# <Response [200]>
# Downloaded: WPR_FY22_IP.pdf
# Downloading  Waypoint REIT FY2021 Results Presentation .....
# WPR_HY22_IP.pdf
# <Response [200]>
# Downloaded: WPR_HY22_IP.pdf
# Downloading  1H21 Results Presentation .....
# WPR_FY21_IP.pdf
# <Response [200]>
# Downloaded: WPR_FY21_IP.pdf
# Downloading  Waypoint REIT FY2020 Results Presentation .....
# WPR_HY21_IP.pdf
# <Response [200]>
# Downloaded: WPR_HY21_IP.pdf
# Downloading  2020 Half Year Results Presentation .....
# WPR_FY20_IP.pdf
# <Response [200]>
# Downloaded: WPR_FY20_IP.pdf
# Downloading  FY2019 Results Presentation .....
# WPR_HY20_IP.pdf
# <Response [200]>
# Downloaded: WPR_HY20_IP.pdf
# Downloading  COF HY26 Results Presentation .....
# COF_HY26_IP.pdf
# Downloading  COF FY25 Results Presentation .....
# COF_FY25_IP.pdf
# Downloading  COF HY25 Results Presentation .....
# COF_HY25_IP.pdf
# Downloading  COF FY24 Results Presentation .....
# COF_FY24_IP.pdf
# Downloading  COF HY24 Results Presentation .....
# COF_HY24_IP.pdf
# Downloading  COF FY23 Results Presentation .....
# COF_FY23_IP.pdf
# Downloading  COF HY23 Results Presentation .....
# COF_HY23_IP.pdf
# Downloading  COF FY22 Results Presentation .....
# COF_FY22_IP.pdf
# <Response [200]>
# Downloaded: COF_FY22_IP.pdf
# Downloading  COF HY22 Results Presentation .....
# COF_HY22_IP.pdf
# <Response [200]>
# Downloaded: COF_HY22_IP.pdf
# Downloading  COF FY21 Results Presentation .....
# COF_FY21_IP.pdf
# <Response [200]>
# Downloaded: COF_FY21_IP.pdf
# Downloading  COF HY21 Results Presentation .....
# COF_HY21_IP.pdf
# <Response [200]>
# Downloaded: COF_HY21_IP.pdf
# Downloading  COF FY20 Results Presentation .....
# COF_FY20_IP.pdf
# <Response [200]>
# Downloaded: COF_FY20_IP.pdf
# Downloading  CMA HY20 Results Presentation .....
# COF_HY20_IP.pdf
# <Response [200]>
# Downloaded: COF_HY20_IP.pdf
# Downloading  CMA FY19 Results Presentation .....
# COF_FY19_IP.pdf
# <Response [200]>
# Downloaded: COF_FY19_IP.pdf
# Downloading  CMA 1H FY19 Results Presentation .....
# COF_HY19_IP.pdf
# <Response [200]>
# Downloaded: COF_HY19_IP.pdf
# Downloading  CMA FY18 Results Presentation .....
# COF_FY18_IP.pdf
# <Response [200]>
# Downloaded: COF_FY18_IP.pdf
# Downloading  CMA 1H18 Results Presentation .....
# COF_HY18_IP.pdf
# <Response [200]>
# Downloaded: COF_HY18_IP.pdf
# Downloading  CMA FY17 Results Presentation .....
# COF_FY17_IP.pdf
# <Response [200]>
# Downloaded: COF_FY17_IP.pdf
# Downloading  CIP HY26 Results Presentation .....
# CIP_HY26_IP.pdf
# Downloading  CIP FY25 Results Presentation .....
# CIP_FY25_IP.pdf
# <Response [200]>
# Downloaded: CIP_FY25_IP.pdf
# Downloading  CIP HY25 Results Presentation .....
# CIP_HY25_IP.pdf
# <Response [200]>
# Downloaded: CIP_HY25_IP.pdf
# Downloading  CIP FY24 Results Presentation .....
# CIP_FY24_IP.pdf
# <Response [200]>
# Downloaded: CIP_FY24_IP.pdf
# Downloading  CIP HY24 Results Presentation .....
# CIP_HY24_IP.pdf
# <Response [200]>
# Downloaded: CIP_HY24_IP.pdf
# Downloading  CIP FY23 Results Presentation .....
# CIP_FY23_IP.pdf
# <Response [200]>
# Downloaded: CIP_FY23_IP.pdf
# Downloading  CIP HY23 Results Presentation .....
# CIP_HY23_IP.pdf
# <Response [200]>
# Downloaded: CIP_HY23_IP.pdf
# Downloading  CIP FY22 Results Presentation .....
# CIP_FY22_IP.pdf
# <Response [200]>
# Downloaded: CIP_FY22_IP.pdf
# Downloading  CIP HY22 Results Presentation .....
# CIP_HY22_IP.pdf
# <Response [200]>
# Downloaded: CIP_HY22_IP.pdf
# Downloading  CIP FY21 Results Presentation .....
# CIP_FY21_IP.pdf
# <Response [200]>
# Downloaded: CIP_FY21_IP.pdf
# Downloading  CIP HY21 Results Presentation .....
# CIP_HY21_IP.pdf
# <Response [200]>
# Downloaded: CIP_HY21_IP.pdf
# Downloading  FY20 Results Presentation, Acquisitions and Equity Raise .....
# CIP_FY20_IP.pdf
# <Response [200]>
# Downloaded: CIP_FY20_IP.pdf
# Downloading  CIP HY20 Results Presentation .....
# CIP_HY20_IP.pdf
# <Response [200]>
# Downloaded: CIP_HY20_IP.pdf
# Downloading  CIP FY19 Results Presentation .....
# CIP_FY19_IP.pdf
# <Response [200]>
# Downloaded: CIP_FY19_IP.pdf
# Downloading  CQR 2026 Half Year Results Presentation .....
# CQR_HY26_IP.pdf
# Downloading  CQR 2025 Full Year Results Presentation .....
# CQR_FY25_IP.pdf
# Downloading  CQR 2025 Half Year Results Presentation .....
# CQR_HY25_IP.pdf
# Downloading  CQR 1H FY24 Results Presentation .....
# CQR_HY24_IP.pdf
# <Response [200]>
# Downloaded: CQR_HY24_IP.pdf
# Downloading  CQR 2023 Half Year Results Presentation .....
# CQR_HY23_IP.pdf
# <Response [200]>
# Downloaded: CQR_HY23_IP.pdf
# Downloading  CQR 2022 Full Year Results Presentation .....
# CQR_FY22_IP.pdf
# <Response [200]>
# Downloaded: CQR_FY22_IP.pdf
# Downloading  Half Year Results Presentation .....
# CQR_HY21_IP.pdf
# <Response [200]>
# Downloaded: CQR_HY21_IP.pdf
# Downloading  FY20 Results Presentation .....
# CQR_FY20_IP.pdf
# <Response [200]>
# Downloaded: CQR_FY20_IP.pdf
# Downloading  FY19 Results Presentation .....
# CQR_FY19_IP.pdf
# <Response [200]>
# Downloaded: CQR_FY19_IP.pdf
# Downloading  HY19 Results Presentation .....
# CQR_HY19_IP.pdf
# <Response [200]>
# Downloaded: CQR_HY19_IP.pdf
# Downloading  Results Presentation FY18 .....
# CQR_FY18_IP.pdf
# <Response [200]>
# Downloaded: CQR_FY18_IP.pdf
# Downloading  Half Year Results Presentation .....
# CQR_HY18_IP.pdf
# <Response [200]>
# Downloaded: CQR_HY18_IP.pdf
# Downloading  HY26 Results Presentation .....
# CQE_HY26_IP.pdf
# Downloading  FY25 Results Presentation .....
# CQE_FY25_IP.pdf
# Downloading  HY25 Results Presentation .....
# CQE_HY25_IP.pdf
# Downloading  FY24 Results Presentation .....
# CQE_FY24_IP.pdf
# Downloading  HY24 Results Presentation .....
# CQE_HY24_IP.pdf
# Downloading  FY23 Results Presentation .....
# CQE_FY23_IP.pdf
# Downloading  CQE 1H FY23 Results Presentation .....
# CQE_HY23_IP.pdf
# <Response [200]>
# Downloaded: CQE_HY23_IP.pdf
# Downloading  CQE FY22 Results Presentation .....
# CQE_FY22_IP.pdf
# <Response [200]>
# Downloaded: CQE_FY22_IP.pdf
# Downloading  CQE FY22 Half Year Results Presentation .....
# CQE_HY22_IP.pdf
# <Response [200]>
# Downloaded: CQE_HY22_IP.pdf
# Downloading  HY21 Results Presentation .....
# CQE_HY21_IP.pdf
# <Response [200]>
# Downloaded: CQE_HY21_IP.pdf
# Downloading  FY20 Results Presentation .....
# CQE_FY20_IP.pdf
# <Response [200]>
# Downloaded: CQE_FY20_IP.pdf
# Downloading  HY20 Results Presentation .....
# CQE_HY20_IP.pdf
# <Response [200]>
# Downloaded: CQE_HY20_IP.pdf
# Downloading  FY19 Results Presentation .....
# CQE_FY19_IP.pdf
# <Response [200]>
# Downloaded: CQE_FY19_IP.pdf
# Downloading  Results Presentation .....
# CQE_HY19_IP.pdf
# <Response [200]>
# Downloaded: CQE_HY19_IP.pdf
# Downloading  FET 30 June 2018 Results Presentation .....
# CQE_FY18_IP.pdf
# <Response [200]>
# Downloaded: CQE_FY18_IP.pdf
# Downloading  HY18 Results Presentation .....
# CQE_HY18_IP.pdf
# <Response [200]>
# Downloaded: CQE_HY18_IP.pdf
# Downloading  FET 30 June 2017 Results Presentation .....
# CQE_FY17_IP.pdf
# <Response [200]>
# Downloaded: CQE_FY17_IP.pdf
# Downloading  HY17 Results Presentation .....
# CQE_HY17_IP.pdf
# <Response [200]>
# Downloaded: CQE_HY17_IP.pdf
# Downloading  FY16 Results Presentation .....
# CQE_FY16_IP.pdf
# <Response [200]>
# Downloaded: CQE_FY16_IP.pdf
# Downloading  Results Presentation - Half Year Ended 31 December 2015 .....
# CQE_HY16_IP.pdf
# <Response [200]>
# Downloaded: CQE_HY16_IP.pdf
# Downloading  FET FY15 Results Presentation .....
# CQE_FY15_IP.pdf
# <Response [200]>
# Downloaded: CQE_FY15_IP.pdf
# Downloading  HY2026 Results Presentation .....
# ARF_HY26_IP.pdf
# Downloading  FY2025 Results presentation .....
# ARF_FY25_IP.pdf
# Downloading  HY2025 Results Presentation .....
# ARF_HY25_IP.pdf
# Downloading  FY2024 Results Presentation .....
# ARF_FY24_IP.pdf
# <Response [200]>
# Downloaded: ARF_FY24_IP.pdf
# Downloading  HY2024 Results Presentation .....
# ARF_HY24_IP.pdf
# <Response [200]>
# Downloaded: ARF_HY24_IP.pdf
# Downloading  FY2023 Results presentation .....
# ARF_FY23_IP.pdf
# <Response [200]>
# Downloaded: ARF_FY23_IP.pdf
# Downloading  HY2023 Results Presentation .....
# ARF_HY23_IP.pdf
# <Response [200]>
# Downloaded: ARF_HY23_IP.pdf
# Downloading  FY22 Annual Results Presentation .....
# ARF_FY22_IP.pdf
# <Response [200]>
# Downloaded: ARF_FY22_IP.pdf
# Downloading  HY2022 Results Presentation .....
# ARF_HY22_IP.pdf
# <Response [200]>
# Downloaded: ARF_HY22_IP.pdf
# Downloading  FY21 Annual Results Presentation .....
# ARF_FY21_IP.pdf
# <Response [200]>
# Downloaded: ARF_FY21_IP.pdf
# Downloading  HY21 Results Presentation .....
# ARF_HY21_IP.pdf
# <Response [200]>
# Downloaded: ARF_HY21_IP.pdf
# Downloading  FY20 Annual Results Presentation .....
# ARF_FY20_IP.pdf
# <Response [200]>
# Downloaded: ARF_FY20_IP.pdf
# Downloading  Arena REIT 2020 Half Year Results Presentation .....
# ARF_HY20_IP.pdf
# <Response [200]>
# Downloaded: ARF_HY20_IP.pdf
# Downloading  FY19 Annual Results presentation .....
# ARF_FY19_IP.pdf
# <Response [200]>
# Downloaded: ARF_FY19_IP.pdf
# Downloading  Arena REIT 2019 Half Year Results Presentation .....
# ARF_HY19_IP.pdf
# <Response [200]>
# Downloaded: ARF_HY19_IP.pdf
# Downloading  FY18 Annual Results presentation .....
# ARF_FY18_IP.pdf
# <Response [200]>
# Downloaded: ARF_FY18_IP.pdf
# Downloading  FY18 Interim Results Presentation .....
# ARF_HY18_IP.pdf
# <Response [200]>
# Downloaded: ARF_HY18_IP.pdf
# Downloading  FY18 Interim Results Presentation .....
# ARF_HY18_IP.pdf
# Downloading  CQR 2026 Half Year  Results Presentation .....
# CLW_HY26_IP.pdf
# Downloading  CLW 2025 Full Year Results presentation .....
# CLW_FY25_IP.pdf
# Downloading  CLW 2025 Half Year Results Presentation .....
# CLW_HY25_IP.pdf
# Downloading  CLW FY23 Full Year Results Presentation .....
# CLW_FY23_IP.pdf
# <Response [200]>
# Downloaded: CLW_FY23_IP.pdf
# Downloading  CLW 2023 Half Year Results Presentation .....
# CLW_HY23_IP.pdf
# <Response [200]>
# Downloaded: CLW_HY23_IP.pdf
# Downloading  CLW FY22 Full Year Results Presentation .....
# CLW_FY22_IP.pdf
# <Response [200]>
# Downloaded: CLW_FY22_IP.pdf
# Downloading  CLW FY22 Half Year Results presentation .....
# CLW_HY22_IP.pdf
# <Response [200]>
# Downloaded: CLW_HY22_IP.pdf
# Downloading  FY20 Results Presentation .....
# CLW_FY20_IP.pdf
# <Response [200]>
# Downloaded: CLW_FY20_IP.pdf
# Downloading  HY20 Results Presentation .....
# CLW_HY20_IP.pdf
# <Response [200]>
# Downloaded: CLW_HY20_IP.pdf
# Downloading  FY19 Results Presentation .....
# CLW_FY19_IP.pdf
# <Response [200]>
# Downloaded: CLW_FY19_IP.pdf
# Downloading  Long WALE REIT HY19 Results Presentation .....
# CLW_HY19_IP.pdf
# <Response [200]>
# Downloaded: CLW_HY19_IP.pdf
# Downloading  Half Year Results Presentation .....
# GMG_HY26_IP.pdf
# Downloading  Full Year Results Presentation .....
# GMG_FY25_IP.pdf
# Downloading  Full Year Results Presentation .....
# GMG_FY24_IP.pdf
# Downloading  Half Year Results Presentation .....
# GMG_HY24_IP.pdf
# Downloading  Full Year Results Presentation .....
# GMG_FY23_IP.pdf
# <Response [200]>
# Downloaded: GMG_FY23_IP.pdf
# Downloading  Half Year Results Presentation .....
# GMG_HY23_IP.pdf
# <Response [200]>
# Downloaded: GMG_HY23_IP.pdf
# Downloading  Full Year Results Presentation .....
# GMG_FY22_IP.pdf
# <Response [200]>
# Downloaded: GMG_FY22_IP.pdf
# Downloading  Half Year Results Presentation .....
# GMG_HY22_IP.pdf
# <Response [200]>
# Downloaded: GMG_HY22_IP.pdf
# Downloading  Full Year Results Presentation .....
# GMG_FY21_IP.pdf
# <Response [200]>
# Downloaded: GMG_FY21_IP.pdf
# Downloading  Half Year Results Presentation .....
# GMG_HY21_IP.pdf
# <Response [200]>
# Downloaded: GMG_HY21_IP.pdf
# Downloading  Full Year Results Presentation .....
# GMG_FY20_IP.pdf
# <Response [200]>
# Downloaded: GMG_FY20_IP.pdf
# Downloading  Half Year Results Presentation .....
# GMG_HY20_IP.pdf
# <Response [200]>
# Downloaded: GMG_HY20_IP.pdf
# Downloading  Full Year Results Presentation .....
# GMG_FY19_IP.pdf
# <Response [200]>
# Downloaded: GMG_FY19_IP.pdf
# Downloading  Half Year Results Presentation .....
# GMG_HY19_IP.pdf
# <Response [200]>
# Downloaded: GMG_HY19_IP.pdf
# Downloading  Full Year Results Presentation .....
# GMG_FY18_IP.pdf
# <Response [200]>
# Downloaded: GMG_FY18_IP.pdf
# Downloading  Half Year Results Presentation .....
# GMG_HY18_IP.pdf
# <Response [200]>
# Downloaded: GMG_HY18_IP.pdf
# Downloading  Full Year Results Presentation .....
# GMG_FY17_IP.pdf
# <Response [200]>
# Downloaded: GMG_FY17_IP.pdf
# Downloading  Half Year Results Presentation .....
# GMG_HY17_IP.pdf
# <Response [200]>
# Downloaded: GMG_HY17_IP.pdf
# Downloading  Full Year Results Presentation .....
# GMG_FY16_IP.pdf
# <Response [200]>
# Downloaded: GMG_FY16_IP.pdf
# Downloading  Half Year Results Presentation .....
# GMG_HY16_IP.pdf
# <Response [200]>
# Downloaded: GMG_HY16_IP.pdf

# %% [markdown]
# # Analyze what announcements are available

# %%
dd.create_announcement_df(ticker_list= ticker_list, limit=100).head()
# Out:
#         id          identifier     fileId  pageCount      symbolId  \
# 0  1909132  XASX:COF:2A1600573  2A1600573          1  COF:AUD:XASX
# 1  1909129  XASX:COF:2A1600570  2A1600570          4  COF:AUD:XASX
# 2  1901199  XASX:COF:2A1596683  2A1596683          2  COF:AUD:XASX
# 3  1874219  XASX:COF:2A1583347  2A1583347          1  COF:AUD:XASX
# 4  1874212  XASX:COF:2A1583345  2A1583345          4  COF:AUD:XASX
#
#            securityName  fileSize                              heading  \
# 0  Centuria Office REIT    169606   June 2025 Distribution Declaration
# 1  Centuria Office REIT     13770          Dividend/Distribution - COF
# 2  Centuria Office REIT    231397             Q3 FY25 Operating Update
# 3  Centuria Office REIT    169175  March 2025 Distribution Declaration
# 4  Centuria Office REIT     13770          Dividend/Distribution - COF
#
#                    dateTime fileType  isPriceSensitive  \
# 0  2025-06-05T23:07:10.000Z      pdf              True
# 1  2025-06-05T23:04:25.000Z      pdf              True
# 2  2025-05-14T23:07:04.000Z      pdf              True
# 3  2025-03-06T22:44:26.000Z      pdf              True
# 4  2025-03-06T22:39:21.000Z      pdf              True
#
#                                        fileKey  \
# 0  announcements/xasx/2025/06/06/2A1600573.pdf
# 1  announcements/xasx/2025/06/06/2A1600570.pdf
# 2  announcements/xasx/2025/05/15/2A1596683.pdf
# 3  announcements/xasx/2025/03/07/2A1583347.pdf
# 4  announcements/xasx/2025/03/07/2A1583345.pdf
#
#                                                types ticker
# 0  [{'id': 4, 'identifier': '4', 'title': 'Divide...    COF
# 1  [{'id': 4, 'identifier': '4', 'title': 'Divide...    COF
# 2  [{'id': 2, 'identifier': '2', 'title': 'Period...    COF
# 3  [{'id': 4, 'identifier': '4', 'title': 'Divide...    COF
# 4  [{'id': 4, 'identifier': '4', 'title': 'Divide...    COF

# %% [markdown]
# # To download specific reports available in Announcement Dataframe

# %%
#Inputs
regex_pattern = r'operating update'
from_date_YYYY_MM_DD="2024-01-31"
to_date_YYYY_MM_DD="2025-03-31",
save_dir="datasets/raw"
limit = 100


dd.download_documents(
    ticker_list=ticker_list,
    from_date_YYYY_MM_DD=from_date_YYYY_MM_DD,
    to_date_YYYY_MM_DD=to_date_YYYY_MM_DD,
    save_dir=save_dir,
    regex_pattern=regex_pattern,
    limit=limit
)
# Out:
# /tmp/ipykernel_5569/1988005279.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ISO_date"] = pd.to_datetime(df['dateTime'])
# Filtered 2 announcements matching the criteria.
# Downloading  Q1 FY25 Operating Update .....
# <Response [200]>
# Downloaded: COF_Q1 FY25 Operating Update
# Downloading  Q3 FY24 Operating Update .....
# <Response [200]>
# Downloaded: COF_Q3 FY24 Operating Update

# %%
tickers_prospectus = [
    "GYG", "DGT", "TEA", "MAC", "CCL", "SYL", "MRE", "WHI", "PCX", "BWN",
    # "SS1", "VFY", "GHM", "BB1", "AAL", "WAG", "D3E", "ORD", "RNV", "RAU",
    # "AXL", "MNC", "PR2", "KM1", "FNR", "I88", "MHM", "LMS", "FUL"
]
