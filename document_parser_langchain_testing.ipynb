# %%
from pathlib import Path

folder = Path(r"datasets\raw")

file_paths = [str(p) for p in folder.iterdir() if p.is_file()]

# %%
#Used to test that document parser py is working properly. 

from document_parser_langchain import DocumentParser
import os

os.environ["DOCLING_ALLOW_EXTERNAL_PLUGINS"] = "true"
out_dir = r"datasets\processed"
dp = DocumentParser(out_dir=out_dir)

for file_path in file_paths:
    dp.ingest_document(file_path=file_path)

# file_path = r"datasets/raw/GMG_FY24_IP.pdf"
# Out:
# Processing file: ABG_FY17_IP.pdf
# [INFO] 2026-03-15 01:18:15,976 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-03-15 01:18:15,978 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-03-15 01:18:15,984 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\chuak\OneDrive\Documents\Projects\LLM-based-information-extraction-for-financial-documents\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-03-15 01:18:15,989 [RapidOCR] main.py:50: Using C:\Users\chuak\OneDrive\Documents\Projects\LLM-based-information-extraction-for-financial-documents\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-03-15 01:18:16,173 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-03-15 01:18:16,173 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# ...
